# %%
print("Hello")
# Out:
# Hello

# %%
a=5
b=6

# %%
a+c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a+c
#
# NameError: name 'c' is not defined

# %%
print(a, b, a+b)
# Out:
# 5 6 11

# %%
type(a)
# Out:
# int

# %%
c="prachi"

# %%
type(c)
# Out:
# str

# %%
for = 6
# Out:
#   Cell In[12], line 1
#     for = 6
#         ^
# SyntaxError: invalid syntax

# %%
a= 3+5j

# %%
type(a)
# Out:
# complex

# %%
b=5.89

# %%
type(b)
# Out:
# float

# %%
a
# Out:
# (3+5j)

# %%
d={"name":"Ankush","age":28}

# %%
d
# Out:
# {'name': 'Ankush', 'age': 28}

# %%
a=5
b=6

# %%
a==b
# Out:
# False

# %%
s={2,2,3,4,5,5}

# %%
s
# Out:
# {2, 3, 4, 5}

# %%
t=(1,2,43,4,4,0)

# %%
type(t)
# Out:
# tuple

# %%
l=[1,2,3,4,5]

# %%
type(l)
# Out:
# list

# %%
num1=5
num2=3

# %%
num1**num2
# Out:
# 125

# %%
5%2
# Out:
# 1

# %%
5//2
# Out:
# 2

# %%
a=5

# %%
a += 2 # a=a+2

# %%
a
# Out:
# 7

# %%
a -= 3

# %%
a
# Out:
# 4

# %%
a **= 3

# %%
a
# Out:
# 64

# %%
a= 5
b=8

# %%
a<=b
# Out:
# True
