# %%
l1 =[1,'mango',True,2+4j,67.89,67.89]

# %%
l1
# Out:
# [1, 'mango', True, (2+4j), 67.89, 67.89]

# %%
type(l1)
# Out:
# list

# %%
l1[1]
# Out:
# 'mango'

# %%
l1[-1]
# Out:
# 67.89

# %%
len(l1)
# Out:
# 6

# %%
l1[1:4]
# Out:
# ['mango', True, (2+4j)]

# %%
l1[start:stop:step]

# %%
l1[1:4:2]
# Out:
# ['mango', (2+4j)]

# %%
l1[::-1]

# %%
l1[:4]
# Out:
# [1, 'mango', True, (2+4j)]

# %%
l1[2:]
# Out:
# [True, (2+4j), 67.89, 67.89]

# %%
l1[-5:-2:2]
# Out:
# ['mango', (2+4j)]

# %%
l1[:]
# Out:
# [1, 'mango', True, (2+4j), 67.89, 67.89]

# %%
l1[::-1]
# Out:
# [67.89, 67.89, (2+4j), True, 'mango', 1]

# %%
l1.append("Apple")

# %%
l1
# Out:
# [1, 'mango', 100, True, (2+4j), 67.89, 67.89, 'Apple', 'Apple', 'Apple']

# %%
l1.insert(2,100)

# %%
l1
# Out:
# [1, 'mango', 100, True, (2+4j), 67.89, 67.89, 'Apple']

# %%
l1.remove('Apple')

# %%
l1
# Out:
# [1, 'mango', 100, True, (2+4j), 67.89, 67.89, 'Apple', 'Apple']

# %%
l1.insert(2,'Apple')

# %%
l1
# Out:
# [1, 'mango', 100, True, (2+4j), 67.89, 67.89, 'Apple', 'Apple']

# %%
l1.remove(101)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 l1.remove(101)
#
# ValueError: list.remove(x): x not in list

# %%
l1.pop(2)
# Out:
# 100

# %%
l1
# Out:
# [1, 'mango', True, (2+4j), 67.89, 67.89, 'Apple', 'Apple']

# %%
l1.pop()
# Out:
# 'Apple'

# %%
l1
# Out:
# [1, 'mango', True, (2+4j), 67.89, 67.89, 'Apple']

# %%
l1.pop(7)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 l1.pop(7)
#
# IndexError: pop index out of range

# %%
del l1[1]

# %%
l1
# Out:
# [1, True, (2+4j), 67.89, 67.89, 'Apple']

# %%
del l1

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
l1
# Out:
# [1, 'mango', True, (2+4j), 67.89, 67.89]

# %%
l1[2]='prachi'

# %%
l1
# Out:
# [1, 'mango', 'prachi', (2+4j), 67.89, 67.89]

# %%
t=(10,20,30)

# %%
t[2]=40
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 t[2]=40
#
# TypeError: 'tuple' object does not support item assignment

# %%
s={1,2,3,4,5,5,6,8,9,8}

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6, 8, 9}

# %%
5 in s
# Out:
# True

# %%
10 in s
# Out:
# False

# %%
s.remove(2)

# %%
s
# Out:
# {1, 3, 4, 5, 6, 8, 9}

# %%
s.remove(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 s.remove(2)
#
# KeyError: 2

# %%
s.discard(2)

# %%
s
# Out:
# {1, 3, 4, 5, 6, 8, 9}

# %%
s.discard(9)

# %%
s
# Out:
# {1, 3, 4, 5, 6, 8}
