# %%
import pandas
print(dir(pandas))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ../../../pip-build-env-xi5zhp6s/overlay/Lib/site-packages/numpy/__init__.cython-30.pxd:1009, in numpy.import_array()
#
# SystemError: <built-in function __import__> returned a result with an exception set
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\__init__.py:25
#      24 try:
# ---> 25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
# ...

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ../../../pip-build-env-xi5zhp6s/overlay/Lib/site-packages/numpy/__init__.cython-30.pxd:1009, in numpy.import_array()
#
# SystemError: <built-in function __import__> returned a result with an exception set
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\__init__.py:25
#      24 try:
# ---> 25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
# ...

# %%
# !pip install pandas
# Out:
# ...
# WARNING: Ignoring invalid distribution ~andas (C:\Users\prach\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\prach\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\prach\AppData\Roaming\Python\Python311\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\prach\\anaconda3\\Lib\\site-packages\\pandas\\_libs\\hashtable.cp311-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution ~andas (C:\Users\prach\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\prach\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\prach\AppData\Roaming\Python\Python311\site-packages)
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# ...

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# File ../../../pip-build-env-xi5zhp6s/overlay/Lib/site-packages/numpy/__init__.cython-30.pxd:1009, in numpy.import_array()
#
# SystemError: <built-in function __import__> returned a result with an exception set
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas as pd
#
# File ~\anaconda3\Lib\site-packages\pandas\__init__.py:56
#      45 # let init-time option registration happen
# ...

# %%
pip install geometry-toolkit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\prach\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\prach\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\prach\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\prach\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\prach\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\prach\AppData\Roaming\Python\Python311\site-packages)
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import geometry_toolkit

# %%
print(dir(geometry_toolkit))
# Out:
# ['__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'circle_area', 'circle_circumference', 'rectangle_area', 'rectangle_perimeter', 'shapes', 'square_area', 'square_perimeter']

# %%
help(geometry_toolkit)
# Out:
# Help on package geometry_toolkit:
#
# NAME
#     geometry_toolkit
#
# PACKAGE CONTENTS
#     shapes
#
# FUNCTIONS
#     circle_area(radius)
#
#     circle_circumference(radius)
#
#     rectangle_area(length, width)
#
#     rectangle_perimeter(length, width)
#
#     square_area(side)
#
#     square_perimeter(side)
#
# DATA
#     __all__ = ['rectangle_area', 'rectangle_perimeter', 'square_area', 'sq...
#
# FILE
#     c:\users\prach\anaconda3\lib\site-packages\geometry_toolkit\__init__.py

# %%
pip show geometry_toolkit
# Out:
# Name: geometry_toolkitNote: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (C:\Users\prach\AppData\Roaming\Python\Python311\site-packages)
# Version: 0.1.0
# Summary: A simple math toolkit package
# Home-page: https://github.com/prachikabra121/geometry_toolkit
# Author: Prachi Kabra
# Author-email: kabraprachi9@gmail.com
# License:
# Location: C:\Users\prach\anaconda3\Lib\site-packages
# Requires:
# Required-by:

# %%
pip list
# Out:
# Package                                  Version
# ---------------------------------------- ------------
# absl-py                                  2.1.0
# aiobotocore                              2.7.0
# aiofiles                                 23.2.1
# aiohttp                                  3.9.3
# aioitertools                             0.7.1
# aiosignal                                1.2.0
# alabaster                                0.7.12
# altair                                   4.2.2
# anaconda-anon-usage                      0.4.3
# anaconda-catalogs                        0.2.0
# anaconda-client                          1.12.3
# anaconda-cloud-auth                      0.1.4
# anaconda-navigator                       2.5.2
# anaconda-project                         0.11.1
# annotated-types                          0.7.0
# anyio                                    4.8.0
# appdirs                                  1.4.4
# archspec                                 0.2.3
# ...
