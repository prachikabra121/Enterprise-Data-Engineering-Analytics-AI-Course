# %%
import numpy as np
import pandas as pd

print(np.__version__)
print(pd.__version__)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\prach\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\prach\anaconda3\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\prach\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
# ...

# %%
# !pip uninstall numpy -y
# !pip install numpy==1.26.4
# Out:
# Found existing installation: numpy 2.4.6
# Uninstalling numpy-2.4.6:
#   Successfully uninstalled numpy-2.4.6
# WARNING: Ignoring invalid distribution ~andas (C:\Users\prach\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\prach\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\prach\anaconda3\Lib\site-packages\~umpy.libs'.
# You can safely remove it manually.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\prach\anaconda3\Lib\site-packages\~umpy'.
# You can safely remove it manually.
# ...
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# ...
# WARNING: Ignoring invalid distribution ~andas (C:\Users\prach\AppData\Roaming\Python\Python311\site-packages)
# ...

# %%
import numpy as np
import pandas as pd

print(np.__version__)
print(pd.__version__)
# Out:
# 1.26.4
# 2.3.3

# %%
prices = pd.Series([250, 480, 125, 999]) 
print(prices)
# Out:
# 0    250
# 1    480
# 2    125
# 3    999
# dtype: int64

# %%
prices
# Out:
# 0    250
# 1    480
# 2    125
# 3    999
# dtype: int64

# %%
students = pd.DataFrame({"Student_name":["Rahul","Priya","Amit","Sneha","Rohan"],
                         "Maths":[85,92,78,95,88],
                         "Science":[98,35,78,27,99],
                         "City":["Delhi","Mumbai","Ahemdabad","Pune","Noida"]})

# %%
students
# Out:
#   Student_name  Maths  Science       City
# 0        Rahul     85       98      Delhi
# 1        Priya     92       35     Mumbai
# 2         Amit     78       78  Ahemdabad
# 3        Sneha     95       27       Pune
# 4        Rohan     88       99      Noida

# %%
students.head(2)
# Out:
#   Student_name  Maths  Science    City
# 0        Rahul     85       98   Delhi
# 1        Priya     92       35  Mumbai

# %%
students.tail(2)
# Out:
#   Student_name  Maths  Science   City
# 3        Sneha     95       27   Pune
# 4        Rohan     88       99  Noida

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student_name  5 non-null      object
#  1   Maths         5 non-null      int64
#  2   Science       5 non-null      int64
#  3   City          5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %%
students["Maths"][0]
# Out:
# 85

# %%
students[["Student_name","Maths"]]
# Out:
#   Student_name  Maths
# 0        Rahul     85
# 1        Priya     92
# 2         Amit     78
# 3        Sneha     95
# 4        Rohan     88

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Rahul", "Priya", "Amit", "Sneha"],
    "Maths": [85, 92, 78, 95],
    "Science": [90, 88, 80, 91]
})

print(df)
# Out:
#     Name  Maths  Science
# 0  Rahul     85       90
# 1  Priya     92       88
# 2   Amit     78       80
# 3  Sneha     95       91

# %%
df
# Out:
#     Name  Maths  Science
# 0  Rahul     85       90
# 1  Priya     92       88
# 2   Amit     78       80
# 3  Sneha     95       91

# %%
df.columns
# Out:
# Index(['Name', 'Maths', 'Science'], dtype='object')

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.index = ["S101","S102","S103","S104"]

# %%
df
# Out:
#        Name  Maths  Science
# S101  Rahul     85       90
# S102  Priya     92       88
# S103   Amit     78       80
# S104  Sneha     95       91

# %%
df.loc["S102"]
# Out:
# Name       Priya
# Maths         92
# Science       88
# Name: S102, dtype: object

# %%
df.loc["S102","Maths"]
# Out:
# 92

# %%
df.loc[["S101","S104"]]
# Out:
#        Name  Maths  Science
# S101  Rahul     85       90
# S104  Sneha     95       91

# %%
df.loc[["S101","S104"],["Name","Maths"]]
# Out:
#        Name  Maths
# S101  Rahul     85
# S104  Sneha     95

# %%
import pandas as pd

df1 = pd.DataFrame({
    "Name": ["Rahul", "Priya", "Amit"],
    "Maths": [85, 92, 78],
    "Science": [90, 87, 80]
})

print(df1)
# Out:
#     Name  Maths  Science
# 0  Rahul     85       90
# 1  Priya     92       87
# 2   Amit     78       80

# %%
df1.loc[1]
# Out:
# Name       Priya
# Maths         92
# Science       87
# Name: 1, dtype: object

# %%
df1.loc[1,"Maths"]
# Out:
# 92

# %%
.iloc

# %%
df
# Out:
#        Name  Maths  Science
# S101  Rahul     85       90
# S102  Priya     92       88
# S103   Amit     78       80
# S104  Sneha     95       91

# %%
df.iloc[1]
# Out:
# Name       Priya
# Maths         92
# Science       88
# Name: S102, dtype: object

# %%
df.iloc[2,1]
# Out:
# 78

# %%
df.iloc[0:2]
# Out:
#        Name  Maths  Science
# S101  Rahul     85       90
# S102  Priya     92       88

# %%
df.iloc[1:3,0:2]
# Out:
#        Name  Maths
# S102  Priya     92
# S103   Amit     78

# %%
df = pd.DataFrame({
    "Emp_ID":[101,102,103,104],
    "Name":["Anand","Riya","Kabir","Sara"],
    "Salary":[85000,75000,95000,90000]
})

# %%
df
# Out:
#    Emp_ID   Name  Salary
# 0     101  Anand   85000
# 1     102   Riya   75000
# 2     103  Kabir   95000
# 3     104   Sara   90000

# %%
df.set_index("Emp_ID",inplace=True)

# %%
df
# Out:
#          Name  Salary
# Emp_ID
# 101     Anand   85000
# 102      Riya   75000
# 103     Kabir   95000
# 104      Sara   90000

# %%
df.loc[103]
# Out:
# Name      Kabir
# Salary    95000
# Name: 103, dtype: object

# %%
df1=df.reset_index()

# %%
df1
# Out:
#    Emp_ID   Name  Salary
# 0     101  Anand   85000
# 1     102   Riya   75000
# 2     103  Kabir   95000
# 3     104   Sara   90000

# %%
df1[df1["Salary"]>85000]
# Out:
#    Emp_ID   Name  Salary
# 2     103  Kabir   95000
# 3     104   Sara   90000

# %%
df2=pd.read_csv(r"C:\Users\prach\Downloads\test (2).csv")

# %%
df2
# Out:
#    Emp_ID   Name Department  Salary
# 0     101  Anand         IT   85000
# 1     102   Riya         HR   75000
# 2     103  Kabir         IT   95000
# 3     104   Sara    Finance   90000

# %%
df3 = pd.read_excel("employee.xlsx")

# %%
df3
# Out:
#    EmployeeID FirstName LastName  DepartmentID  Salary   HireDate
# 0           1      John      Doe            10    5500 2020-01-15
# 1           2      Jane    Smith            20    7000 2018-03-25
# 2           3     Alice  Johnson            10    4800 2021-07-10
# 3           4       Bob    Brown            30    6200 2019-11-05
# 4           5   Charlie    Davis            20    7200 2017-05-20
# 5           6       Eve   Wilson            30    4000 2022-02-14

# %%
df3[["FirstName","LastName","HireDate"]]
# Out:
#   FirstName LastName   HireDate
# 0      John      Doe 2020-01-15
# 1      Jane    Smith 2018-03-25
# 2     Alice  Johnson 2021-07-10
# 3       Bob    Brown 2019-11-05
# 4   Charlie    Davis 2017-05-20
# 5       Eve   Wilson 2022-02-14

# %%
df4=pd.read_csv("tab_ex.txt",sep="|")

# %%
df4
# Out:
#    Emp_ID   Name Department  Salary
# 0     101  Anand         IT   85000
# 1     102   Riya         HR   75000
# 2     103  Kabir         IT   95000
# 3     104   Sara    Finance   90000

# %%
df5=pd.read_json("json_data.json")

# %%
df5
# Out:
#    Emp_ID   Name Department  Salary
# 0     101  Anand         IT   85000
# 1     102   Riya         HR   75000
# 2     103  Kabir         IT   95000

# %%
df5.shape
# Out:
# (3, 4)

# %%
df5.columns
# Out:
# Index(['Emp_ID', 'Name', 'Department', 'Salary'], dtype='object')

# %%
df5.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df5.dtypes
# Out:
# Emp_ID         int64
# Name          object
# Department    object
# Salary         int64
# dtype: object

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Emp_ID      3 non-null      int64
#  1   Name        3 non-null      object
#  2   Department  3 non-null      object
#  3   Salary      3 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 228.0+ bytes

# %%
df5.describe()
# Out:
#        Emp_ID   Salary
# count     3.0      3.0
# mean    102.0  85000.0
# std       1.0  10000.0
# min     101.0  75000.0
# 25%     101.5  80000.0
# 50%     102.0  85000.0
# 75%     102.5  90000.0
# max     103.0  95000.0
