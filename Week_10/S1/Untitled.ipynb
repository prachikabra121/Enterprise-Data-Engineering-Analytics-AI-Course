# %%
def test(**kwargs):
    for i,j in kwargs:

# %%
----only contain one expression
----cannot use loop
----cannot use multiple return statements
----poor readability for complex logic
----cannot have docstring
----hard to debug
----not suitable for large programs

# %%
numbers = [10,20,0,5]

# %%
result=list(map(lambda x:100/x,numbers))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result=list(map(lambda x:100/x,numbers))
#
# Cell In[4], line 1, in <lambda>(x)
# ----> 1 result=list(map(lambda x:100/x,numbers))
#
# ZeroDivisionError: division by zero

# %%
nuber_iter = iter(numbers)

# %%
next(nuber_iter)
# Out:
# 10

# %%
next(nuber_iter)
# Out:
# 20

# %%
next(nuber_iter)
# Out:
# 0

# %%
next(nuber_iter)
# Out:
# 5

# %%
next(nuber_iter)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 next(nuber_iter)
#
# StopIteration:

# %%
def sq(x):
    return x**2

# %%
l = list(map(sq,[2,3,4,6,7,8,1013,45]))

# %%
l
# Out:
# [4, 9, 16, 36, 49, 64, 1026169, 2025]

# %%
def is_odd(x):
    return x%2!=0

# %%
l= list(filter(is_odd,[2,3,45,8,90,45,23]))

# %%
l
# Out:
# [3, 45, 45, 23]

# %%
from functools import reduce

reduce(function,iterable)

# %%
from functools import reduce

# %%
l=reduce(lambda x,y:x+y,[2,3,4,5,6,7,8])

# %%
l
# Out:
# 35

# %%
import pandas as pd

data = {
    'Month': ['Jan', 'Jan', 'Feb', 'Feb', 'Mar', 'Mar'],
    'Product': ['Laptop', 'Mobile', 'Laptop', 'Mobile', 'Laptop', 'Mobile'],
    'Sales': [50000, 30000, 60000, 40000, 55000, 35000]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#   Month Product  Sales
# 0   Jan  Laptop  50000
# 1   Jan  Mobile  30000
# 2   Feb  Laptop  60000
# 3   Feb  Mobile  40000
# 4   Mar  Laptop  55000
# 5   Mar  Mobile  35000

# %%
pivot_df = df.pivot(index='Month',columns='Product',values='Sales')

# %%
pivot_df
# Out:
# Product  Laptop  Mobile
# Month
# Feb       60000   40000
# Jan       50000   30000
# Mar       55000   35000
